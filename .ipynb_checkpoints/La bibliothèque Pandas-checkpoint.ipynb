# %% [markdown]
# ###  Lire un fichier CSV avec Pandas

# %%
import pandas as pd

# %%
file ="C:/Users/abdou/OneDrive/Bureau/Formation data science avec python/foods_info.csv"
foods_info=pd.read_csv(file)

# %%
print(type(foods_info))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Exploration du DataFrame

# %%
foods_info.head()
#affiche par defaut que les 5 premieres lignes
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
#    Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# ...

# %%
foods_info.head(2)
#precision du nombre de lignes à afficher
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
#
#    Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# 0    2499.0      684.0        2.32        1.5      60.0          7.0
# 1    2499.0      684.0        2.32        1.5      60.0          7.0
#
#    FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# 0      51.368       21.021        3.043           215.0
# 1      50.489       23.426        3.012           219.0
#
# [2 rows x 36 columns]

# %%
print(foods_info.head())
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
#    Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# ...

# %%
#extraction du nom des colonnes :
column_foods = foods_info.columns
print(column_foods)
print("On possede",len(column_foods),"colonnes") #36 colonnes
# Out:
# Index(['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)',
#        'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)',
#        'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)',
#        'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)',
#        'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)',
#        'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)',
#        'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)', 'Vit_D_mcg',
#        'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)', 'FA_Mono_(g)', 'FA_Poly_(g)',
#        'Cholestrl_(mg)'],
#       dtype='object')
# On possede 36 colonnes

# %%
#dimension du data frame 
print(foods_info.shape)
# Out:
# (8618, 36)

# %% [markdown]
# ### Sélectionner une ligne

# %%
#loc[]
#retourne un objet series

# %%
foods_info.loc[0]
#loc ignore automatiquement le header
# Out:
# NDB_No                         1001
# Shrt_Desc          BUTTER WITH SALT
# Water_(g)                     15.87
# Energ_Kcal                      717
# Protein_(g)                    0.85
# Lipid_Tot_(g)                 81.11
# Ash_(g)                        2.11
# Carbohydrt_(g)                 0.06
# Fiber_TD_(g)                      0
# Sugar_Tot_(g)                  0.06
# Calcium_(mg)                     24
# Iron_(mg)                      0.02
# Magnesium_(mg)                    2
# Phosphorus_(mg)                  24
# Potassium_(mg)                   24
# Sodium_(mg)                     643
# Zinc_(mg)                      0.09
# Copper_(mg)                       0
# Manganese_(mg)                    0
# Selenium_(mcg)                    1
# Vit_C_(mg)                        0
# Thiamin_(mg)                  0.005
# Riboflavin_(mg)               0.034
# Niacin_(mg)                   0.042
# Vit_B6_(mg)                   0.003
# Vit_B12_(mcg)                  0.17
# ...

# %% [markdown]
# ###  Les types de données Pandas

# %%
#Objet : equivalent de string et list python

# %%
#datetime

# %%
#int, flo ,bool

# %%
#dataframe.dtype : retourne chaque colonne et son type associé
print(foods_info.dtypes)
# Out:
# NDB_No               int64
# Shrt_Desc           object
# Water_(g)          float64
# Energ_Kcal           int64
# Protein_(g)        float64
# Lipid_Tot_(g)      float64
# Ash_(g)            float64
# Carbohydrt_(g)     float64
# Fiber_TD_(g)       float64
# Sugar_Tot_(g)      float64
# Calcium_(mg)       float64
# Iron_(mg)          float64
# Magnesium_(mg)     float64
# Phosphorus_(mg)    float64
# Potassium_(mg)     float64
# Sodium_(mg)        float64
# Zinc_(mg)          float64
# Copper_(mg)        float64
# Manganese_(mg)     float64
# Selenium_(mcg)     float64
# Vit_C_(mg)         float64
# Thiamin_(mg)       float64
# Riboflavin_(mg)    float64
# Niacin_(mg)        float64
# Vit_B6_(mg)        float64
# Vit_B12_(mcg)      float64
# Vit_A_IU           float64
# Vit_A_RAE          float64
# Vit_E_(mg)         float64
# Vit_D_mcg          float64
# Vit_D_IU           float64
# Vit_K_(mcg)        float64
# FA_Sat_(g)         float64
# FA_Mono_(g)        float64
# ...

# %% [markdown]
#  ### Sélectionner plusieurs lignes

# %%
# Data frame contenant les lignes d'index 3,4,5 et 6
foods_info.loc[3:6]
# Out:
#    NDB_No         Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 3    1004       CHEESE BLUE      42.41         353        21.40
# 4    1005      CHEESE BRICK      41.11         371        23.24
# 5    1006       CHEESE BRIE      48.42         334        20.75
# 6    1007  CHEESE CAMEMBERT      51.80         300        19.80
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
# 5          27.68     2.70            0.45           0.0           0.45  ...
# 6          24.26     3.68            0.46           0.0           0.46  ...
#
#    Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# 3     721.0      198.0        0.25        0.5      21.0          2.4
# 4    1080.0      292.0        0.26        0.5      22.0          2.5
# ...

# %%
# Data frame contenant les lignes d'index 2,5 et 10

# %%
#methode 1 
two_five_ten= [2,5,10]
foods_info.loc[two_five_ten]
# Out:
#     NDB_No             Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 2     1003  BUTTER OIL ANHYDROUS       0.24         876         0.28
# 5     1006           CHEESE BRIE      48.42         334        20.75
# 10    1011          CHEESE COLBY      38.20         394        23.76
#
#     Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 2           99.48     0.00            0.00           0.0           0.00  ...
# 5           27.68     2.70            0.45           0.0           0.45  ...
# 10          32.11     3.36            2.57           0.0           0.52  ...
#
#     Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# 2     3069.0      840.0        2.80        1.8      73.0          8.6
# 5      592.0      174.0        0.24        0.5      20.0          2.3
# 10     994.0      264.0        0.28        0.6      24.0          2.7
#
#     FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# ...

# %%
#methode 2 
foods_info.loc[[2,5,10]]
# Out:
#     NDB_No             Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 2     1003  BUTTER OIL ANHYDROUS       0.24         876         0.28
# 5     1006           CHEESE BRIE      48.42         334        20.75
# 10    1011          CHEESE COLBY      38.20         394        23.76
#
#     Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 2           99.48     0.00            0.00           0.0           0.00  ...
# 5           27.68     2.70            0.45           0.0           0.45  ...
# 10          32.11     3.36            2.57           0.0           0.52  ...
#
#     Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# 2     3069.0      840.0        2.80        1.8      73.0          8.6
# 5      592.0      174.0        0.24        0.5      20.0          2.3
# 10     994.0      264.0        0.28        0.6      24.0          2.7
#
#     FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# ...

# %% [markdown]
# Selectionner les 5 dernieres lignes :

# %%
num_rows = foods_info.shape[0]
foods_info.loc[num_rows-5:num_rows-1]
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
#       Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 8613          25.10    13.40            0.00           0.0            0.0
# 8614           0.84     2.97            5.41           0.0            0.0
# 8615           0.00     0.86           73.14           0.0           73.2
# 8616           1.40     1.30            2.00           0.0            0.0
# 8617           0.50     1.20            0.00           0.0            0.0
#
# ...

# %%
foods_info.loc[foods_info.shape[0]-5:foods_info.shape[0]-1]
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
#       Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 8613          25.10    13.40            0.00           0.0            0.0
# 8614           0.84     2.97            5.41           0.0            0.0
# 8615           0.00     0.86           73.14           0.0           73.2
# 8616           1.40     1.30            2.00           0.0            0.0
# 8617           0.50     1.20            0.00           0.0            0.0
#
# ...

# %% [markdown]
# ### Sélectionner une colonne plutôt qu'une ligne

# %%
#object Series represantant la colonne "NDB_No"
NDB_col = foods_info['NDB_No']
print(NDB_col)
# Out:
# 0        1001
# 1        1002
# 2        1003
# 3        1004
# 4        1005
#         ...
# 8613    83110
# 8614    90240
# 8615    90480
# 8616    90560
# 8617    93600
# Name: NDB_No, Length: 8618, dtype: int64

# %%
# 2e methode en faisant intervenir une variable pour le nom de la colonne

# %%
protein = foods_info['Protein_(g)']

# %%
cholesterol = foods_info['Cholestrl_(mg)']

# %% [markdown]
# ### Sélectionner plusieurs colonnes

# %%
zinc_copper = foods_info[['Zinc_(mg)','Copper_(mg)']]
zinc_copper
# Out:
#       Zinc_(mg)  Copper_(mg)
# 0          0.09        0.000
# 1          0.05        0.016
# 2          0.01        0.001
# 3          2.66        0.040
# 4          2.60        0.024
# ...         ...          ...
# 8613       1.10        0.100
# 8614       1.55        0.033
# 8615       0.19        0.020
# 8616       1.00        0.400
# 8617       1.00        0.250
#
# [8618 rows x 2 columns]

# %%
foods_info[['Shrt_Desc','Selenium_(mcg)','Thiamin_(mg)']]
# Out:
#                        Shrt_Desc  Selenium_(mcg)  Thiamin_(mg)
# 0               BUTTER WITH SALT             1.0         0.005
# 1       BUTTER WHIPPED WITH SALT             1.0         0.005
# 2           BUTTER OIL ANHYDROUS             0.0         0.001
# 3                    CHEESE BLUE            14.5         0.029
# 4                   CHEESE BRICK            14.5         0.014
# ...                          ...             ...           ...
# 8613             MACKEREL SALTED            73.4         0.020
# 8614  SCALLOP (BAY&SEA) CKD STMD            21.7         0.012
# 8615                  SYRUP CANE             0.7         0.130
# 8616                   SNAIL RAW            27.4         0.010
# 8617            TURTLE GREEN RAW            16.8         0.120
#
# [8618 rows x 3 columns]

# %% [markdown]
# ### Cas pratique

# %% [markdown]
#  Selectionner et afficher seulement les colonnes qui utilisent comme unité de mesure les grammes :

# %%
columns = foods_info.columns.tolist()

# %%
gram_columns = []
for c in columns:
    if c.endswith("(g)"):
        gram_columns.append(c)
        
gram_df = foods_info[gram_columns]

# %%
gram_df
# Out:
#       Water_(g)  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0         15.87         0.85          81.11     2.11            0.06
# 1         15.87         0.85          81.11     2.11            0.06
# 2          0.24         0.28          99.48     0.00            0.00
# 3         42.41        21.40          28.74     5.11            2.34
# 4         41.11        23.24          29.68     3.18            2.79
# ...         ...          ...            ...      ...             ...
# 8613      43.00        18.50          25.10    13.40            0.00
# 8614      70.25        20.54           0.84     2.97            5.41
# 8615      26.00         0.00           0.00     0.86           73.14
# 8616      79.20        16.10           1.40     1.30            2.00
# 8617      78.50        19.80           0.50     1.20            0.00
#
#       Fiber_TD_(g)  Sugar_Tot_(g)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)
# ...

# %% [markdown]
# ## Manipulation de donnees avac pandas

# %%
#Score = 2 x protein -0.75 x Lipid

# %%
col_names = foods_info.columns.tolist()
print(col_names)
# Out:
# ['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)', 'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)', 'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)', 'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)', 'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)', 'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)', 'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)', 'Vit_D_mcg', 'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)', 'FA_Mono_(g)', 'FA_Poly_(g)', 'Cholestrl_(mg)']

# %%
foods_info.head(3)
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
#
#    Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# 0    2499.0      684.0        2.32        1.5      60.0          7.0
# 1    2499.0      684.0        2.32        1.5      60.0          7.0
# 2    3069.0      840.0        2.80        1.8      73.0          8.6
#
#    FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# ...

# %% [markdown]
# ### Transformer une colonne

# %%
div_1000 = foods_info['Iron_(mg)']/1000

# %%
div_1000
# Out:
# 0       0.00002
# 1       0.00016
# 2       0.00000
# 3       0.00031
# 4       0.00043
#          ...
# 8613    0.00140
# 8614    0.00058
# 8615    0.00360
# 8616    0.00350
# 8617    0.00140
# Name: Iron_(mg), Length: 8618, dtype: float64

# %%
iron =foods_info['Iron_(mg)']
iron
# Out:
# 0       0.02
# 1       0.16
# 2       0.00
# 3       0.31
# 4       0.43
#         ...
# 8613    1.40
# 8614    0.58
# 8615    3.60
# 8616    3.50
# 8617    1.40
# Name: Iron_(mg), Length: 8618, dtype: float64

# %%
#A jouter 100 à chaque valeur dans la colonne et retourne donc un nouvel object Series
add_100 = foods_info['Iron_(mg)']+100

# %%
#Soustraire 100 à chaque aleur de la colonne et retourne un object Series
sub_100 = foods_info['Iron_(mg)']-100

# %%
#Multiplie chaque valeur de la colonne par 2 
mult_2 = foods_info['Iron_(mg)']*2

# %% [markdown]
# ### Operations mathematiques entre colonnes

# %%
water_energy = foods_info['Water_(g)']*foods_info["Energ_Kcal"]

# %%
print(water_energy)
# Out:
# 0       11378.79
# 1       11378.79
# 2         210.24
# 3       14970.73
# 4       15251.81
#           ...
# 8613    13115.00
# 8614     7797.75
# 8615     6994.00
# 8616     7128.00
# 8617     6986.50
# Length: 8618, dtype: float64

# %%
grams_prof_protein_per_gram_of_water = foods_info['Protein_(g)']/foods_info['Water_(g)']

# %%
miligrams_of_calcium_and_iron = foods_info['Calcium_(mg)']+foods_info['Iron_(mg)']

# %%
print(grams_prof_protein_per_gram_of_water)
print(miligrams_of_calcium_and_iron)
# Out:
# 0       0.053560
# 1       0.053560
# 2       1.166667
# 3       0.504598
# 4       0.565313
#           ...
# 8613    0.430233
# 8614    0.292384
# 8615    0.000000
# 8616    0.203283
# 8617    0.252229
# Length: 8618, dtype: float64
# 0        24.02
# 1        24.16
# 2         4.00
# 3       528.31
# 4       674.43
#          ...
# 8613     67.40
# 8614     10.58
# 8615     16.60
# 8616     13.50
# 8617    119.40
# Length: 8618, dtype: float64

# %% [markdown]
# ### Creer un indice nutritionnel

# %% [markdown]
# Score = 2 x protein -0.75 x Lipid

# %%
Score = 2* foods_info['Protein_(g)']- 0.75* foods_info['Lipid_Tot_(g)']

# %%
print(Score)
# Out:
# 0      -59.1325
# 1      -59.1325
# 2      -74.0500
# 3       21.2450
# 4       24.2200
#          ...
# 8613    18.1750
# 8614    40.4500
# 8615     0.0000
# 8616    31.1500
# 8617    39.2250
# Length: 8618, dtype: float64

# %% [markdown]
# ### Normaliser des colonnes

# %%
# diviser par la valeur max de la colonne

# %%
#valeur max de colonne "Energ_Kcal"
max_calories = foods_info['Energ_Kcal'].max()
max_calories
# Out:
# 902

# %%
normalized_calories = foods_info['Energ_Kcal']/foods_info['Energ_Kcal'].max()
print(normalized_calories)
# Out:
# 0       0.794900
# 1       0.794900
# 2       0.971175
# 3       0.391353
# 4       0.411308
#           ...
# 8613    0.338137
# 8614    0.123060
# 8615    0.298226
# 8616    0.099778
# 8617    0.098670
# Name: Energ_Kcal, Length: 8618, dtype: float64

# %%
normalized_prot = foods_info['Protein_(g)']/foods_info['Protein_(g)'].max()
normalized_fat = foods_info['Lipid_Tot_(g)']/foods_info['Lipid_Tot_(g)'].max()
print(normalized_lipd)
print(normalized_prot)
# Out:
# 0       0.8111
# 1       0.8111
# 2       0.9948
# 3       0.2874
# 4       0.2968
#          ...
# 8613    0.2510
# 8614    0.0084
# 8615    0.0000
# 8616    0.0140
# 8617    0.0050
# Name: Lipid_Tot_(g), Length: 8618, dtype: float64
# 0       0.009624
# 1       0.009624
# 2       0.003170
# 3       0.242301
# 4       0.263134
#           ...
# 8613    0.209466
# 8614    0.232563
# 8615    0.000000
# 8616    0.182292
# 8617    0.224185
# Name: Protein_(g), Length: 8618, dtype: float64

# %% [markdown]
# ### Creer une nouvelle colonne

# %%
iron_grams = foods_info['Iron_(mg)']*1000
foods_info['Iron_(g)'] = iron_grams

# %%
foods_info
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %%
foods_info['normalized_protein'] = normalized_prot
foods_info['normalized_Fat'] = normalized_fat

# %%
foods_info.head(5)
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
#    Vit_D_IU  Vit_K_(mcg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  \
# ...

# %% [markdown]
# ### Creer un indice nutritionnel normalisé

# %% [markdown]
# Score = 2 x Normalized_Protein - 075 x Normalized_Fat

# %%
foods_info['Norm_Nutr_Index'] = 2*foods_info["normalized_protein"]-0.75*foods_info['normalized_Fat']

# %%
foods_info['Norm_Nutr_Index']
# Out:
# 0      -0.589077
# 1      -0.589077
# 2      -0.739759
# 3       0.269051
# 4       0.303668
#           ...
# 8613    0.230681
# 8614    0.458827
# 8615    0.000000
# 8616    0.354083
# 8617    0.444620
# Name: Norm_Nutr_Index, Length: 8618, dtype: float64

# %%
del foods_info['Norm_Nutr_index']

# %% [markdown]
# ### Trier un DataFrame

# %%
# sort_values()

# %%
foods_info.sort_values("Sodium_(mg)")
#On trie on fonction de Sodium_(mg)
# Out:
#       NDB_No                                          Shrt_Desc  Water_(g)  \
# 760     4666  SHORTENING INDUSTRIAL SOY (PARTIALLY HYDR )&CO...       0.00
# 758     4664  OIL INDUSTRIAL SOY (PARTHYDR ) PALM  ICINGS & ...       0.00
# 405     3168                            BABYFOOD JUC APPL&PEACH      89.00
# 761     4667  SHORTENING INDUS SOY (PART HYDR ) FOR BAKING &...       0.00
# 2269    9111            GRAPEFRUIT RAW PINK&RED&WHITE ALL AREAS      90.89
# ...      ...                                                ...        ...
# 8184   35092               WILLOW LEAVES IN OIL (ALASKA NATIVE)      28.00
# 8185   35093          WILLOW YOUNG LEAVES CHOPD (ALASKA NATIVE)      68.70
# 8195   35139                     SQUASH INDIAN CKD BLD (NAVAJO)      96.21
# 8251   35199       PRICKLY PEARS BRLD (NORTHERN PLAINS INDIANS)      75.83
# 8267   35231               SEA LION STELLER FAT (ALASKA NATIVE)       4.70
#
# ...

# %%
#Trie le data frame et remplace l'ancien data frame
foods_info.sort_values("Sodium_(mg)",inplace=True)

# %%
foods_info.sort_values("Sodium_(mg)",inplace=True,ascending=False)
#On trie de façon descendante

# %% [markdown]
# Trier en foction du facteur nutritioniste de façon descendante

# %%
foods_info.sort_values("Norm_Nutr_Index",inplace=True,ascending=False)

# %%
foods_info
# Out:
#       NDB_No                                          Shrt_Desc  Water_(g)  \
# 4991   16423           SOY PROT ISOLATE K TYPE CRUDE PROT BASIS       4.98
# 6155   19177                           GELATINS DRY PDR UNSWTND      13.00
# 216     1258             EGG WHITE DRIED STABILIZED GLUCOSE RED       6.53
# 124     1136         EGG WHITE DRIED PDR STABILIZED GLUCOSE RED       8.54
# 8152   35055   SEAL BEARDED (OOGRUK) MEAT DRIED (ALASKA NATIVE)      11.60
# ...      ...                                                ...        ...
# 657     4511            OIL SAFFLOWER SALAD OR COOKING HI OLEIC       0.00
# 737     4642                 OIL INDUSTRIAL MID-OLEIC SUNFLOWER       0.00
# 790     4701                      OIL INDUSTRIAL SOY FULLY HYDR       0.00
# 791     4702                   OIL INDUSTRIAL CTTNSD FULLY HYDR       0.00
# 757     4663  OIL INDUSTRIAL PALM KERNEL (HYDROGENATED) FILL...       0.08
#
# ...
